# %% [markdown]
# ## Import the Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('darkgrid')

# %% [markdown]
# ## Data Analysis & Visualization

# %%
# read the dataset
df = pd.read_csv('Churn_Modelling.csv')

# see the first five rows of df
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
#shape
df.shape
# Out:
# (10000, 14)

# %%
#information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %%
#checking duplicate rows()
df.duplicated().sum()
# Out:
# 0

# %%
# dropping the irrelevant columns 
df.drop(columns=["RowNumber", "CustomerId", "Surname"], inplace = True)

# %%
# check the value counts of "Geography" column.
df_geography = df['Geography'].value_counts()
df_geography
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %%
# performing univarient eda on "Geography" column. 
plt.figure(figsize=(12,6))
sns.barplot(x=df_geography, y=df_geography.index)
plt.xlabel('Value Counts of Customers Geographically',fontsize = 16, color='black')
plt.ylabel('Geography Names',fontsize = 16, color='black')
plt.title('Customers Geographically Data',fontsize = 16, color='black')
plt.show()

# %%
#value_count of gender
df['Gender'].value_counts()
# Out:
# Gender
# Male      5457
# Female    4543
# Name: count, dtype: int64

# %% [markdown]
# ## Apply One Hot Encoding Technique on Gender & Geography Column¶

# %%
df=pd.get_dummies(df,columns=['Gender','Geography'],drop_first=True)

# %% [markdown]
# ## Let's Handle the Imbalanced Target Column and Balanced it

# %%
from sklearn.utils import resample
# Separate majority and minority classes
majority_class = df[df['Exited'] == 0]
minority_class = df[df['Exited'] == 1]

# Upsample the minority class
upsampled_minority = resample(minority_class,
                              replace=True,  # Sample with replacement
                              n_samples=len(majority_class),  # Match the number of majority class samples
                              random_state=42)  # Set random state for reproducibility

# Combine the upsampled minority class with the majority class
balanced_data = pd.concat([majority_class, upsampled_minority])

# %%
# check the target_balanced_data
balanced_data
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 1             608   41       1   83807.86              1          0
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# 6             822   50       7       0.00              2          1
# 8             501   44       4  142051.07              2          0
# ...           ...  ...     ...        ...            ...        ...
# 5701          625   49       4  128504.76              1          1
# 9337          466   47       5  102085.72              1          1
# 4345          720   46       3   97042.60              1          1
# 1085          803   42       5       0.00              1          1
# 3694          608   33       4       0.00              1          1
#
#       IsActiveMember  EstimatedSalary  Exited  Gender_Male  Geography_Germany  \
# 1                  1        112542.58       0        False              False
# 3                  0         93826.63       0        False              False
# 4                  1         79084.10       0        False              False
# 6                  1         10062.80       0         True              False
# 8                  1         74940.50       0         True              False
# ...              ...              ...     ...          ...                ...
# 5701               0        126812.63       1        False               True
# 9337               1        183536.24       1        False               True
# 4345               1        133516.51       1         True               True
# 1085               0        196466.83       1         True              False
# 3694               0         79304.38       1        False              False
#
#       Geography_Spain
# 1                True
# 3               False
# 4                True
# 6               False
# 8               False
# ...               ...
# 5701            False
# 9337            False
# 4345            False
# 1085            False
# 3694            False
#
# [15926 rows x 12 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
balanced_data['Exited'].value_counts()
# Out:
# Exited
# 0    7963
# 1    7963
# Name: count, dtype: int64

# %%
balanced_data.isnull().sum()
# Out:
# CreditScore          0
# Age                  0
# Tenure               0
# Balance              0
# NumOfProducts        0
# HasCrCard            0
# IsActiveMember       0
# EstimatedSalary      0
# Exited               0
# Gender_Male          0
# Geography_Germany    0
# Geography_Spain      0
# dtype: int64

# %%
balanced_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15926 entries, 1 to 3694
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CreditScore        15926 non-null  int64
#  1   Age                15926 non-null  int64
#  2   Tenure             15926 non-null  int64
#  3   Balance            15926 non-null  float64
#  4   NumOfProducts      15926 non-null  int64
#  5   HasCrCard          15926 non-null  int64
#  6   IsActiveMember     15926 non-null  int64
#  7   EstimatedSalary    15926 non-null  float64
#  8   Exited             15926 non-null  int64
#  9   Gender_Male        15926 non-null  bool
#  10  Geography_Germany  15926 non-null  bool
#  11  Geography_Spain    15926 non-null  bool
# dtypes: bool(3), float64(2), int64(7)
# memory usage: 1.3 MB

# %% [markdown]
# ## Split the Data for model Training and Testing

# %%
x = balanced_data.drop('Exited',axis=1)
y = balanced_data['Exited']

# %%
# use sklearn for train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
#applying standards scaler
scaler = StandardScaler()

x_train_scaled = scaler.fit_transform(xtrain)
x_test_scaled = scaler.transform(xtest)

# %% [markdown]
# ## Model Building - Artificial - Neural - Network - ANN

# %%
model = Sequential()
model.add(Dense(11, activation='relu', input_dim = 11))
model.add(Dense(11, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 11)                132
#
#  dense_1 (Dense)             (None, 11)                132
#
#  dense_2 (Dense)             (None, 1)                 12
#
# =================================================================
# Total params: 276
# Trainable params: 276
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
history = model.fit(x_train_scaled, ytrain, epochs = 100, validation_split=0.2)
# Out:
# Epoch 1/100
# 319/319 [==============================] - 0s 988us/step - loss: 0.4598 - accuracy: 0.7785 - val_loss: 0.4579 - val_accuracy: 0.7759
# Epoch 2/100
# 319/319 [==============================] - 0s 899us/step - loss: 0.4573 - accuracy: 0.7817 - val_loss: 0.4561 - val_accuracy: 0.7822
# Epoch 3/100
# 319/319 [==============================] - 0s 944us/step - loss: 0.4546 - accuracy: 0.7828 - val_loss: 0.4533 - val_accuracy: 0.7885
# Epoch 4/100
# 319/319 [==============================] - 0s 989us/step - loss: 0.4524 - accuracy: 0.7842 - val_loss: 0.4507 - val_accuracy: 0.7892
# Epoch 5/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4507 - accuracy: 0.7870 - val_loss: 0.4497 - val_accuracy: 0.7861
# Epoch 6/100
# 319/319 [==============================] - 0s 978us/step - loss: 0.4492 - accuracy: 0.7857 - val_loss: 0.4477 - val_accuracy: 0.7877
# Epoch 7/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4476 - accuracy: 0.7860 - val_loss: 0.4481 - val_accuracy: 0.7857
# Epoch 8/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4464 - accuracy: 0.7867 - val_loss: 0.4476 - val_accuracy: 0.7896
# Epoch 9/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4451 - accuracy: 0.7847 - val_loss: 0.4445 - val_accuracy: 0.7900
# Epoch 10/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4447 - accuracy: 0.7878 - val_loss: 0.4456 - val_accuracy: 0.7892
# Epoch 11/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4429 - accuracy: 0.7897 - val_loss: 0.4467 - val_accuracy: 0.7849
# Epoch 12/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4426 - accuracy: 0.7910 - val_loss: 0.4444 - val_accuracy: 0.7924
# Epoch 13/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4415 - accuracy: 0.7887 - val_loss: 0.4470 - val_accuracy: 0.7838
# Epoch 14/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4412 - accuracy: 0.7879 - val_loss: 0.4436 - val_accuracy: 0.7900
# Epoch 15/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4402 - accuracy: 0.7903 - val_loss: 0.4447 - val_accuracy: 0.7896
# Epoch 16/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4401 - accuracy: 0.7935 - val_loss: 0.4436 - val_accuracy: 0.7896
# Epoch 17/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4386 - accuracy: 0.7886 - val_loss: 0.4418 - val_accuracy: 0.7881
# Epoch 18/100
# 319/319 [==============================] - 0s 984us/step - loss: 0.4383 - accuracy: 0.7902 - val_loss: 0.4424 - val_accuracy: 0.7892
# Epoch 19/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4379 - accuracy: 0.7911 - val_loss: 0.4411 - val_accuracy: 0.7885
# Epoch 20/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4375 - accuracy: 0.7943 - val_loss: 0.4437 - val_accuracy: 0.7885
# Epoch 21/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4369 - accuracy: 0.7947 - val_loss: 0.4419 - val_accuracy: 0.7904
# Epoch 22/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4364 - accuracy: 0.7943 - val_loss: 0.4430 - val_accuracy: 0.7900
# Epoch 23/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4356 - accuracy: 0.7935 - val_loss: 0.4431 - val_accuracy: 0.7885
# Epoch 24/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4357 - accuracy: 0.7961 - val_loss: 0.4422 - val_accuracy: 0.7877
# Epoch 25/100
# 319/319 [==============================] - 0s 998us/step - loss: 0.4356 - accuracy: 0.7948 - val_loss: 0.4410 - val_accuracy: 0.7877
# Epoch 26/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4349 - accuracy: 0.7946 - val_loss: 0.4443 - val_accuracy: 0.7881
# Epoch 27/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4347 - accuracy: 0.7931 - val_loss: 0.4411 - val_accuracy: 0.7928
# Epoch 28/100
# 319/319 [==============================] - 0s 984us/step - loss: 0.4345 - accuracy: 0.7932 - val_loss: 0.4398 - val_accuracy: 0.7908
# Epoch 29/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4329 - accuracy: 0.7961 - val_loss: 0.4409 - val_accuracy: 0.7865
# Epoch 30/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4339 - accuracy: 0.7944 - val_loss: 0.4433 - val_accuracy: 0.7900
# Epoch 31/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4330 - accuracy: 0.7942 - val_loss: 0.4423 - val_accuracy: 0.7900
# Epoch 32/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4325 - accuracy: 0.7940 - val_loss: 0.4445 - val_accuracy: 0.7877
# Epoch 33/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4326 - accuracy: 0.7941 - val_loss: 0.4423 - val_accuracy: 0.7869
# Epoch 34/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4320 - accuracy: 0.7952 - val_loss: 0.4424 - val_accuracy: 0.7853
# Epoch 35/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4322 - accuracy: 0.7947 - val_loss: 0.4433 - val_accuracy: 0.7881
# Epoch 36/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4312 - accuracy: 0.7973 - val_loss: 0.4443 - val_accuracy: 0.7885
# Epoch 37/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4314 - accuracy: 0.7973 - val_loss: 0.4427 - val_accuracy: 0.7904
# Epoch 38/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4316 - accuracy: 0.7943 - val_loss: 0.4420 - val_accuracy: 0.7881
# Epoch 39/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4307 - accuracy: 0.7947 - val_loss: 0.4422 - val_accuracy: 0.7853
# Epoch 40/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4301 - accuracy: 0.7962 - val_loss: 0.4443 - val_accuracy: 0.7916
# Epoch 41/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4306 - accuracy: 0.7968 - val_loss: 0.4431 - val_accuracy: 0.7908
# Epoch 42/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4310 - accuracy: 0.7967 - val_loss: 0.4406 - val_accuracy: 0.7924
# Epoch 43/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4300 - accuracy: 0.7957 - val_loss: 0.4429 - val_accuracy: 0.7853
# Epoch 44/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4298 - accuracy: 0.7958 - val_loss: 0.4415 - val_accuracy: 0.7904
# Epoch 45/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4297 - accuracy: 0.7939 - val_loss: 0.4442 - val_accuracy: 0.7869
# Epoch 46/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4296 - accuracy: 0.7967 - val_loss: 0.4447 - val_accuracy: 0.7885
# Epoch 47/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4289 - accuracy: 0.7958 - val_loss: 0.4440 - val_accuracy: 0.7885
# Epoch 48/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4290 - accuracy: 0.7964 - val_loss: 0.4423 - val_accuracy: 0.7896
# Epoch 49/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4292 - accuracy: 0.7956 - val_loss: 0.4434 - val_accuracy: 0.7900
# Epoch 50/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4288 - accuracy: 0.7975 - val_loss: 0.4448 - val_accuracy: 0.7920
# Epoch 51/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4287 - accuracy: 0.7965 - val_loss: 0.4428 - val_accuracy: 0.7845
# Epoch 52/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4290 - accuracy: 0.7946 - val_loss: 0.4453 - val_accuracy: 0.7877
# Epoch 53/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4280 - accuracy: 0.7989 - val_loss: 0.4459 - val_accuracy: 0.7885
# Epoch 54/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4286 - accuracy: 0.7971 - val_loss: 0.4441 - val_accuracy: 0.7892
# Epoch 55/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4285 - accuracy: 0.7969 - val_loss: 0.4442 - val_accuracy: 0.7896
# Epoch 56/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4279 - accuracy: 0.7961 - val_loss: 0.4428 - val_accuracy: 0.7912
# Epoch 57/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4286 - accuracy: 0.7966 - val_loss: 0.4437 - val_accuracy: 0.7885
# Epoch 58/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4279 - accuracy: 0.7950 - val_loss: 0.4462 - val_accuracy: 0.7877
# Epoch 59/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4278 - accuracy: 0.7994 - val_loss: 0.4468 - val_accuracy: 0.7857
# Epoch 60/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4281 - accuracy: 0.7974 - val_loss: 0.4458 - val_accuracy: 0.7877
# Epoch 61/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4276 - accuracy: 0.7984 - val_loss: 0.4442 - val_accuracy: 0.7877
# Epoch 62/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4278 - accuracy: 0.7969 - val_loss: 0.4442 - val_accuracy: 0.7885
# Epoch 63/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4266 - accuracy: 0.7970 - val_loss: 0.4440 - val_accuracy: 0.7892
# Epoch 64/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4267 - accuracy: 0.8010 - val_loss: 0.4450 - val_accuracy: 0.7885
# Epoch 65/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4269 - accuracy: 0.8002 - val_loss: 0.4450 - val_accuracy: 0.7912
# Epoch 66/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4264 - accuracy: 0.7989 - val_loss: 0.4432 - val_accuracy: 0.7936
# Epoch 67/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4259 - accuracy: 0.7997 - val_loss: 0.4466 - val_accuracy: 0.7885
# Epoch 68/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4256 - accuracy: 0.7993 - val_loss: 0.4472 - val_accuracy: 0.7920
# Epoch 69/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4261 - accuracy: 0.7993 - val_loss: 0.4441 - val_accuracy: 0.7908
# Epoch 70/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4253 - accuracy: 0.8005 - val_loss: 0.4459 - val_accuracy: 0.7928
# Epoch 71/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4254 - accuracy: 0.7988 - val_loss: 0.4448 - val_accuracy: 0.7912
# Epoch 72/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4249 - accuracy: 0.8006 - val_loss: 0.4447 - val_accuracy: 0.7924
# Epoch 73/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4248 - accuracy: 0.8013 - val_loss: 0.4440 - val_accuracy: 0.7959
# Epoch 74/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4246 - accuracy: 0.7990 - val_loss: 0.4458 - val_accuracy: 0.7924
# Epoch 75/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4245 - accuracy: 0.7989 - val_loss: 0.4424 - val_accuracy: 0.7940
# Epoch 76/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4239 - accuracy: 0.8012 - val_loss: 0.4452 - val_accuracy: 0.7900
# Epoch 77/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4244 - accuracy: 0.7997 - val_loss: 0.4452 - val_accuracy: 0.7900
# Epoch 78/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4239 - accuracy: 0.8017 - val_loss: 0.4485 - val_accuracy: 0.7932
# Epoch 79/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4235 - accuracy: 0.7997 - val_loss: 0.4442 - val_accuracy: 0.7928
# Epoch 80/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4237 - accuracy: 0.7992 - val_loss: 0.4466 - val_accuracy: 0.7932
# Epoch 81/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4231 - accuracy: 0.8010 - val_loss: 0.4444 - val_accuracy: 0.7932
# Epoch 82/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4238 - accuracy: 0.8008 - val_loss: 0.4441 - val_accuracy: 0.7936
# Epoch 83/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4224 - accuracy: 0.8016 - val_loss: 0.4450 - val_accuracy: 0.7928
# Epoch 84/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4234 - accuracy: 0.7998 - val_loss: 0.4445 - val_accuracy: 0.7940
# Epoch 85/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4231 - accuracy: 0.8007 - val_loss: 0.4439 - val_accuracy: 0.7932
# Epoch 86/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4226 - accuracy: 0.8025 - val_loss: 0.4456 - val_accuracy: 0.7963
# Epoch 87/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4220 - accuracy: 0.8012 - val_loss: 0.4453 - val_accuracy: 0.7967
# Epoch 88/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4219 - accuracy: 0.8042 - val_loss: 0.4436 - val_accuracy: 0.8002
# Epoch 89/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4223 - accuracy: 0.8038 - val_loss: 0.4434 - val_accuracy: 0.7959
# Epoch 90/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4214 - accuracy: 0.8028 - val_loss: 0.4457 - val_accuracy: 0.7932
# Epoch 91/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4216 - accuracy: 0.8045 - val_loss: 0.4444 - val_accuracy: 0.7963
# Epoch 92/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4208 - accuracy: 0.8019 - val_loss: 0.4483 - val_accuracy: 0.7916
# Epoch 93/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4210 - accuracy: 0.8025 - val_loss: 0.4428 - val_accuracy: 0.7967
# Epoch 94/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4213 - accuracy: 0.8016 - val_loss: 0.4410 - val_accuracy: 0.7983
# Epoch 95/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4208 - accuracy: 0.8006 - val_loss: 0.4432 - val_accuracy: 0.7983
# Epoch 96/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4205 - accuracy: 0.8020 - val_loss: 0.4446 - val_accuracy: 0.7955
# Epoch 97/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4211 - accuracy: 0.8030 - val_loss: 0.4436 - val_accuracy: 0.7943
# Epoch 98/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4198 - accuracy: 0.8021 - val_loss: 0.4437 - val_accuracy: 0.7932
# Epoch 99/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4200 - accuracy: 0.8017 - val_loss: 0.4441 - val_accuracy: 0.8046
# Epoch 100/100
# 319/319 [==============================] - 0s 1ms/step - loss: 0.4206 - accuracy: 0.8026 - val_loss: 0.4424 - val_accuracy: 0.8006

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

# %%
prediction = model.predict(x_test_scaled)
# Out:
# 100/100 [==============================] - 0s 564us/step

# %%
y_pred = np.where(prediction > 0.5, 1, 0)

# %%
accuracy_score(ytest, y_pred)
# Out:
# 0.7984934086629002
